# %% [markdown]
# <a href="https://colab.research.google.com/github/adcaceres69/Ensamble_Boosting/blob/main/Desafio_CrossValidation_ARMANDO_CACERES_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error,  mean_absolute_error, r2_score
from sklearn.metrics import classification_report, f1_score, confusion_matrix
from sklearn.preprocessing import OneHotEncoder, StandardScaler

from sklearn.metrics import mean_absolute_percentage_error

# me importa todas las metricas (?)
from sklearn import metrics

# %%
# 1. Preparación de Datos:
# leyendo los datos
features = pd.read_csv('/dengue_features_train.csv')
labels = pd.read_csv('/dengue_labels_train.csv')

# Unimos los datos en base a 'city', 'year' y 'weekofyear'
data = pd.merge(features, labels, on=['city', 'year', 'weekofyear'])

# %%
#data = data.iloc[:, 2:]

# %%
data.isna().sum()
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# station_max_temp_c                        20
# station_min_temp_c                        14
# station_precip_mm                         22
# total_cases                                0
# dtype: int64

# %%
col_a_inter = ['ndvi_ne','ndvi_nw','ndvi_se','ndvi_sw','precipitation_amt_mm',
                'reanalysis_air_temp_k','reanalysis_avg_temp_k','reanalysis_dew_point_temp_k',
                'reanalysis_max_air_temp_k','reanalysis_min_air_temp_k','reanalysis_precip_amt_kg_per_m2',
                'reanalysis_relative_humidity_percent','reanalysis_sat_precip_amt_mm',
                'reanalysis_specific_humidity_g_per_kg','reanalysis_tdtr_k',
                'station_avg_temp_c','station_diur_temp_rng_c','station_max_temp_c',
                'station_min_temp_c','station_precip_mm']

# %% [markdown]
# * La función interpolate de pandas permite rellenar los valores nulos en una columna basándose en los valores existentes. Es útil para datos que tienen una tendencia temporal

# %%
for column in col_a_inter:
    data[column].interpolate(method='linear', inplace=True)

# %%
## para borrar
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1456 entries, 0 to 1455
# Data columns (total 25 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   city                                   1456 non-null   object
#  1   year                                   1456 non-null   int64
#  2   weekofyear                             1456 non-null   int64
#  3   week_start_date                        1456 non-null   object
#  4   ndvi_ne                                1456 non-null   float64
#  5   ndvi_nw                                1456 non-null   float64
#  6   ndvi_se                                1456 non-null   float64
#  7   ndvi_sw                                1456 non-null   float64
#  8   precipitation_amt_mm                   1456 non-null   float64
#  9   reanalysis_air_temp_k                  1456 non-null   float64
#  10  reanalysis_avg_temp_k                  1456 non-null   float64
#  11  reanalysis_dew_point_temp_k            1456 non-null   float64
#  12  reanalysis_max_air_temp_k              1456 non-null   float64
#  13  reanalysis_min_air_temp_k              1456 non-null   float64
#  14  reanalysis_precip_amt_kg_per_m2        1456 non-null   float64
#  15  reanalysis_relative_humidity_percent   1456 non-null   float64
#  16  reanalysis_sat_precip_amt_mm           1456 non-null   float64
#  17  reanalysis_specific_humidity_g_per_kg  1456 non-null   float64
#  18  reanalysis_tdtr_k                      1456 non-null   float64
#  19  station_avg_temp_c                     1456 non-null   float64
#  20  station_diur_temp_rng_c                1456 non-null   float64
#  21  station_max_temp_c                     1456 non-null   float64
#  22  station_min_temp_c                     1456 non-null   float64
#  23  station_precip_mm                      1456 non-null   float64
#  24  total_cases                            1456 non-null   int64
# dtypes: float64(20), int64(3), object(2)
# memory usage: 295.8+ KB

# %%
# Codificación One-Hot para la variable categórica 'city'
encoder = OneHotEncoder()
city_encoded = encoder.fit_transform(data['city'].values.reshape(-1, 1))
city_df = pd.DataFrame(city_encoded.toarray(), columns=encoder.get_feature_names_out(['city']))
data = pd.concat([data, city_df], axis=1)
data.drop('city', axis=1, inplace=True)

# Eliminamos la columna 'week_start_date' por ser de tipo fecha
data.drop('week_start_date', axis=1, inplace=True)

### para borrar - cuando quite estas columnas no mejoraron las metricas del RFR
#data.drop('city_iq', axis=1, inplace=True)
#data.drop('city_sj', axis=1, inplace=True)
### fin para borrar

# cuando quite estas columnas empeoraron las metricas
# quito tambien estas 2 columnas para ver la diferencia
#data.drop('year', axis=1, inplace=True)
#data.drop('weekofyear', axis=1, inplace=True)
######

# Dividimos los datos en conjuntos de entrenamiento y prueba
X = data.drop('total_cases', axis=1)
y = data['total_cases']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1456 entries, 0 to 1455
# Data columns (total 25 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   year                                   1456 non-null   int64
#  1   weekofyear                             1456 non-null   int64
#  2   ndvi_ne                                1456 non-null   float64
#  3   ndvi_nw                                1456 non-null   float64
#  4   ndvi_se                                1456 non-null   float64
#  5   ndvi_sw                                1456 non-null   float64
#  6   precipitation_amt_mm                   1456 non-null   float64
#  7   reanalysis_air_temp_k                  1456 non-null   float64
#  8   reanalysis_avg_temp_k                  1456 non-null   float64
#  9   reanalysis_dew_point_temp_k            1456 non-null   float64
#  10  reanalysis_max_air_temp_k              1456 non-null   float64
#  11  reanalysis_min_air_temp_k              1456 non-null   float64
#  12  reanalysis_precip_amt_kg_per_m2        1456 non-null   float64
#  13  reanalysis_relative_humidity_percent   1456 non-null   float64
#  14  reanalysis_sat_precip_amt_mm           1456 non-null   float64
#  15  reanalysis_specific_humidity_g_per_kg  1456 non-null   float64
#  16  reanalysis_tdtr_k                      1456 non-null   float64
#  17  station_avg_temp_c                     1456 non-null   float64
#  18  station_diur_temp_rng_c                1456 non-null   float64
#  19  station_max_temp_c                     1456 non-null   float64
#  20  station_min_temp_c                     1456 non-null   float64
#  21  station_precip_mm                      1456 non-null   float64
#  22  total_cases                            1456 non-null   int64
#  23  city_iq                                1456 non-null   float64
#  24  city_sj                                1456 non-null   float64
# dtypes: float64(22), int64(3)
# memory usage: 295.8 KB

# %%
X.isna().sum()
# Out:
# year                                     0
# weekofyear                               0
# ndvi_ne                                  0
# ndvi_nw                                  0
# ndvi_se                                  0
# ndvi_sw                                  0
# precipitation_amt_mm                     0
# reanalysis_air_temp_k                    0
# reanalysis_avg_temp_k                    0
# reanalysis_dew_point_temp_k              0
# reanalysis_max_air_temp_k                0
# reanalysis_min_air_temp_k                0
# reanalysis_precip_amt_kg_per_m2          0
# reanalysis_relative_humidity_percent     0
# reanalysis_sat_precip_amt_mm             0
# reanalysis_specific_humidity_g_per_kg    0
# reanalysis_tdtr_k                        0
# station_avg_temp_c                       0
# station_diur_temp_rng_c                  0
# station_max_temp_c                       0
# station_min_temp_c                       0
# station_precip_mm                        0
# city_iq                                  0
# city_sj                                  0
# dtype: int64

# %%
data.head()
# Out:
#    year  weekofyear   ndvi_ne   ndvi_nw   ndvi_se   ndvi_sw  \
# 0  1990          18  0.122600  0.103725  0.198483  0.177617
# 1  1990          19  0.169900  0.142175  0.162357  0.155486
# 2  1990          20  0.032250  0.172967  0.157200  0.170843
# 3  1990          21  0.128633  0.245067  0.227557  0.235886
# 4  1990          22  0.196200  0.262200  0.251200  0.247340
#
#    precipitation_amt_mm  reanalysis_air_temp_k  reanalysis_avg_temp_k  \
# 0                 12.42             297.572857             297.742857
# 1                 22.82             298.211429             298.442857
# 2                 34.54             298.781429             298.878571
# 3                 15.36             298.987143             299.228571
# 4                  7.52             299.518571             299.664286
#
#    reanalysis_dew_point_temp_k  ...  reanalysis_specific_humidity_g_per_kg  \
# 0                   292.414286  ...                              14.012857
# 1                   293.951429  ...                              15.372857
# 2                   295.434286  ...                              16.848571
# 3                   295.310000  ...                              16.672857
# 4                   295.821429  ...                              17.210000
#
#    reanalysis_tdtr_k  station_avg_temp_c  station_diur_temp_rng_c  \
# 0           2.628571           25.442857                 6.900000
# 1           2.371429           26.714286                 6.371429
# 2           2.300000           26.714286                 6.485714
# 3           2.428571           27.471429                 6.771429
# 4           3.014286           28.942857                 9.371429
#
#    station_max_temp_c  station_min_temp_c  station_precip_mm  total_cases  \
# 0                29.4                20.0               16.0            4
# 1                31.7                22.2                8.6            5
# 2                32.2                22.8               41.4            4
# 3                33.3                23.3                4.0            3
# 4                35.0                23.9                5.8            6
#
#    city_iq  city_sj
# 0      0.0      1.0
# 1      0.0      1.0
# 2      0.0      1.0
# 3      0.0      1.0
# 4      0.0      1.0
#
# [5 rows x 25 columns]

# %%
#(data[data.columns[2:23]]).head() # sin las 2 primeras ni las 2 ultimas

# %%
# 2. Construcción del Modelo:

model = RandomForestRegressor(n_estimators=100, random_state=42)
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
# 3. Evaluación del Modelo:

# Error Absoluto medio:
mae = mean_absolute_error(y_test, y_pred)
print(f"Error Absoluto Medio: {mae}\n")

# Error cuadrático medio:
mse = mean_squared_error(y_test, y_pred)#, squared=False) - esto te devuelve la raiz el error cuadrado medio
print(f"Error cuadrático medio: {mse}\n")
mse2 = mean_squared_error(y_test, y_pred, squared=False)
print(f"Raiz del Error cuadrático medio: {mse2}\n")

# Coeficiente de determinacion:
r2 = r2_score(y_test,  y_pred)
print(f"Coeficiente de Determinación R^2: {r2}\n")

# Raiz del Error cuadrado medio:
#rmse = np.sqrt(mse)
#print(f"Raíz del Error cuadrado medio: {rmse}\n")

# error absoluto medio en porcentaje
mape = mean_absolute_percentage_error(y_test, y_pred)
print(f"Error absoluto medio en porcentaje: {mape}\n")
# Out:
# Error Absoluto Medio: 13.008695652173914
#
# Error cuadrático medio: 812.9836718535469
#
# Raiz del Error cuadrático medio: 28.512868530780043
#
# Coeficiente de Determinación R^2: 0.6702778920575148
#
# Error absoluto medio en porcentaje: 1160011839946964.2

# %% [markdown]
# * Error Absoluto Medio (Mean Absolute Error, MAE): Representa el error promedio entre las predicciones del modelo y los valores reales. Un MAE de 13.72, como en tu ejemplo, indica que, en promedio, tus predicciones se desvían del valor real en 13.72 unidades. Es una métrica fácil de interpretar porque tiene las mismas unidades que la variable objetivo. Cuanto más cercano a 0 esté el MAE, mejor será el modelo.
#
# * Error Cuadrático Medio (Mean Squared Error, MSE): Es el promedio de los errores cuadrados entre las predicciones y los valores reales. Da más peso a los errores grandes, lo que puede ser útil si consideras que los errores grandes son más problemáticos que los pequeños. En tu caso, un MSE de 914.93 sugiere que los errores pueden ser significativos, pero su interpretación directa no es tan intuitiva como el MAE porque está en unidades cuadradas. La raíz cuadrada del MSE (RMSE) es una métrica relacionada que podría ser más interpretable ya que está en las mismas unidades que la variable objetivo.
#
# * Raíz del Error Cuadrado Medio (Root Mean Squared Error, RMSE): Es la raíz de la media de los errores cuadrados entre las predicciones y los valores reales. Un RMSE de 28.98.
#
# * Coeficiente de Determinación R^2: Es una métrica que indica cuánta variación de la variable objetivo es explicada por el modelo. Varía entre 0 y 1, donde un valor más alto indica que el modelo explica una mayor proporción de la variación. Un R^2 de 0.6289 (o 62.89%) sugiere que tu modelo explica aproximadamente el 62.89% de la variación en tus datos, lo cual puede considerarse como una buena señal, dependiendo del contexto y de la naturaleza de los datos. Sin embargo, hay que tener cuidado al interpretar R^2 ya que un modelo más complejo (con más características) podría inflar artificialmente este valor.
#
# Al interpretar estas métricas, es importante considerarlas en conjunto y también en el contexto de tu problema específico. Por ejemplo, dependiendo de la aplicación, un MAE de 13.72 podría ser aceptable o no. Además, es útil comparar estas métricas con las de otros modelos para determinar cuál tiene un rendimiento superior.

# %%
# Valores reales vs Valores predichos
plt.scatter(y_test, y_pred)
plt.xlabel('Valores reales')
plt.ylabel('Valores predichos')
plt.title('Valores reales vs Valores predichos')

# Línea de referencia perfecta (predicción perfecta)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')

plt.show()

# %% [markdown]
# * "analizando" los valores de feature_importance

# %%
# Interpretación del Modelo - features_importance:
feature_names = X_train.columns
importances = model.feature_importances_

# Ordena las características por importancia
indices = np.argsort(importances)[::-1]

plt.figure(figsize=(12, 6))
plt.title("Importancia de las Características")
plt.bar(range(X_train.shape[1]), importances[indices], align="center")
plt.xticks(range(X_train.shape[1]), [feature_names[i] for i in indices], rotation=90)
plt.xlim([-1, X_train.shape[1]])
plt.show()

# %% [markdown]
# * ~podria ademas correr el ForestRegressor sin las columnas de years y weekofyear---- (28/10/23~) -- EMPEORARON LAS METRICAS

# %% [markdown]
# ## CROSS-VALIDATION RFR

# %%
from sklearn.model_selection import cross_val_score

# Instancia del modelo
forest = RandomForestRegressor(n_estimators=100, random_state=42)

# Validación cruzada
forest_scores = cross_val_score(forest, X, y, cv=5, scoring='neg_mean_squared_error')

# Convertimos a RMSE (Root Mean Squared Error)
forest_rmse_scores = np.sqrt(-forest_scores)

# Mostramos resultados
print("Puntuaciones para RandomForestRegressor:", forest_rmse_scores)
print("Media:", forest_rmse_scores.mean())
print("Desviación estándar:", forest_rmse_scores.std())
# Out:
# Puntuaciones para RandomForestRegressor: [77.73038374 40.94872271 31.68355134 22.71602084 13.28347668]
# Media: 37.272431060227326
# Desviación estándar: 22.221411488172922

# %% [markdown]
# # Ensamblado
# * Bagging (Bootstrap Aggregating)
# Método: Bagging implica crear múltiples conjuntos de datos a partir de muestreos con reemplazo (bootstrap) y entrenar un modelo en cada conjunto. Las predicciones se realizan promediando (para regresión) o votando (para clasificación) las predicciones de cada modelo.

# %%
from sklearn.datasets import make_regression

# Datos ficticios para ilustrar
X, y = make_regression(n_samples=1000, n_features=20, noise=0.1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Entrenamiento del modelo
rf = RandomForestRegressor(n_estimators=100)
rf.fit(X_train, y_train)

# Predicción y evaluación
y_pred = rf.predict(X_test)

# %% [markdown]
# EVALUANDO con Cross_Validation_score

# %%
#from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import cross_val_score

# Crear un modelo Bagging con RFR como base
bagging_rfr = BaggingRegressor(estimator=RandomForestRegressor(n_estimators=100), n_estimators=10, random_state=42)

# Calcular las puntuaciones de validación cruzada
scores = cross_val_score(bagging_rfr, X, y, cv=5, scoring='r2')  # Estamos usando R^2 como métrica

# Mostrar las puntuaciones
print("Puntuaciones R^2 para cada fold:", scores)
print("Media de puntuaciones R^2:", scores.mean())
print("Desviación estándar de puntuaciones R^2:", scores.std())
# Out:
# Puntuaciones R^2 para cada fold: [0.81767925 0.81513855 0.828701   0.83206913 0.84824557]
# Media de puntuaciones R^2: 0.8283667003789874
# Desviación estándar de puntuaciones R^2: 0.011816892778095542

# %% [markdown]
# ### Graficando las predicciones del ensamblado - bagging

# %%
# Valores reales vs Valores predichos
plt.scatter(y_test, y_pred)
plt.xlabel('Valores reales')
plt.ylabel('Valores predichos')
plt.title('Valores reales vs Valores predichos')

# Línea de referencia perfecta (predicción perfecta)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')

plt.show()

# %% [markdown]
# * Boosting
# Método: Boosting se refiere al proceso de convertir una colección de modelos débiles en un modelo fuerte ajustando iterativamente los modelos a los errores de los modelos anteriores.
# Modelos comúnmente utilizados: Gradient Boosted Trees (GradientBoostingRegressor o GradientBoostingClassifier en scikit-learn) y XGBoost.

# %%
from sklearn.ensemble import GradientBoostingRegressor

# Datos ficticios para ilustrar
X, y = make_regression(n_samples=1000, n_features=20, noise=0.1)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Entrenamiento del modelo
gbr = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1)
gbr.fit(X_train, y_train)

# Predicción y evaluación
y_pred = gbr.predict(X_test)

# %% [markdown]
# EVALUANDO con Cross_Validation_score

# %%
# Crear un modelo AdaBoost con RFR como base
boosting_rfr = AdaBoostRegressor(estimator=RandomForestRegressor(n_estimators=100), n_estimators=50, random_state=42)

# Calcular las puntuaciones de validación cruzada
scores = cross_val_score(boosting_rfr, X, y, cv=5, scoring='r2')  # Estamos usando R^2 como métrica

# Mostrar las puntuaciones
print("Puntuaciones R^2 para cada fold:", scores)
print("Media de puntuaciones R^2:", scores.mean())
print("Desviación estándar de puntuaciones R^2:", scores.std())
# Out:
# Puntuaciones R^2 para cada fold: [0.88512303 0.85328762 0.87237368 0.85321397 0.87564662]
# Media de puntuaciones R^2: 0.8679289813581148
# Desviación estándar de puntuaciones R^2: 0.012695303204948803

# %% [markdown]
# Estos resultados muestran las métricas de evaluación para dos modelos de ensamblado: Bagging y Boosting; con cross validation, analicemos los resultado,
#
# Los resultados que proporcionaste indican las puntuaciones 2R2 (coeficiente de determinación) de los modelos Bagging y Boosting cuando se aplica la validación cruzada.
#
# Bagging con RandomForestRegressor (RFR):
#
# * Puntuaciones 2R2 para cada fold: Las puntuaciones oscilan entre aproximadamente 0.729 y 0.781.
# * Media de puntuaciones 2R2: 0.751, lo que indica que, en promedio, el modelo de Bagging explica el 75.1% de la varianza en los datos.
# * Desviación estándar: 0.0178, lo que indica una variabilidad relativamente baja en las puntuaciones entre los diferentes folds.
#
# Boosting con RandomForestRegressor (RFR):
#
# * Puntuaciones 2R2 para cada fold: Las puntuaciones oscilan entre aproximadamente 0.785 y 0.822.
# * Media de puntuaciones 2R2: 0.8006, lo que indica que, en promedio, el modelo de Boosting explica el 80.06% de la varianza en los datos.
# * Desviación estándar: 0.0129, lo que indica una variabilidad aún menor en las puntuaciones entre los diferentes folds en comparación con el modelo de Bagging.
#
# Análisis:
#
# El modelo de Boosting tiene un rendimiento ligeramente mejor que el modelo de Bagging en términos de la media de 2R2.
# La desviación estándar para el modelo de Boosting es también menor que la del modelo de Bagging, lo que sugiere que el modelo de Boosting es más estable a través de diferentes divisiones de los datos (folds).
# Ambos modelos tienen un buen rendimiento, pero el Boosting con RFR parece ser el más robusto y preciso de los dos basándonos en estos resultados.
# En resumen, dado estos dos modelos y basándome en los resultados de la validación cruzada, el modelo de Boosting con RFR es mejor debido a su mayor precisión y estabilidad.
#
# Sin embargo, también es esencial considerar otros factores, como el tiempo de entrenamiento, la interpretabilidad y las necesidades específicas del problema antes de tomar una decisión final.

# %% [markdown]
# ### Graficando las predicciones del ensamblado - boosting

# %%
# Valores reales vs Valores predichos
plt.scatter(y_test, y_pred)
plt.xlabel('Valores reales')
plt.ylabel('Valores predichos')
plt.title('Valores reales vs Valores predichos')

# Línea de referencia perfecta (predicción perfecta)
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], color='red', linestyle='--')

plt.show()

# %% [markdown]
# # desde Aqui el modelo de SVR

# %%
# 1. Preparación de Datos:

# Suponiendo que tus datos están en "features.csv" y "labels.csv"
features = pd.read_csv('/dengue_features_train.csv')
labels = pd.read_csv('/dengue_labels_train.csv')

# Unimos los datos en base a 'city', 'year' y 'weekofyear'
data = pd.merge(features, labels, on=['city', 'year', 'weekofyear'])

# %%
data.isna().sum()
# Out:
# city                                       0
# year                                       0
# weekofyear                                 0
# week_start_date                            0
# ndvi_ne                                  194
# ndvi_nw                                   52
# ndvi_se                                   22
# ndvi_sw                                   22
# precipitation_amt_mm                      13
# reanalysis_air_temp_k                     10
# reanalysis_avg_temp_k                     10
# reanalysis_dew_point_temp_k               10
# reanalysis_max_air_temp_k                 10
# reanalysis_min_air_temp_k                 10
# reanalysis_precip_amt_kg_per_m2           10
# reanalysis_relative_humidity_percent      10
# reanalysis_sat_precip_amt_mm              13
# reanalysis_specific_humidity_g_per_kg     10
# reanalysis_tdtr_k                         10
# station_avg_temp_c                        43
# station_diur_temp_rng_c                   43
# station_max_temp_c                        20
# station_min_temp_c                        14
# station_precip_mm                         22
# total_cases                                0
# dtype: int64

# %%
col_a_inter = ['ndvi_ne','ndvi_nw','ndvi_se','ndvi_sw','precipitation_amt_mm',
                'reanalysis_air_temp_k','reanalysis_avg_temp_k','reanalysis_dew_point_temp_k',
                'reanalysis_max_air_temp_k','reanalysis_min_air_temp_k','reanalysis_precip_amt_kg_per_m2',
                'reanalysis_relative_humidity_percent','reanalysis_sat_precip_amt_mm',
                'reanalysis_specific_humidity_g_per_kg','reanalysis_tdtr_k',
                'station_avg_temp_c','station_diur_temp_rng_c','station_max_temp_c',
                'station_min_temp_c','station_precip_mm']

# %%
for column in col_a_inter:
    data[column].interpolate(method='linear', inplace=True)

# %%
# Codificación One-Hot para la variable categórica 'city'
encoder = OneHotEncoder()
city_encoded = encoder.fit_transform(data['city'].values.reshape(-1, 1))
city_df = pd.DataFrame(city_encoded.toarray(), columns=encoder.get_feature_names_out(['city']))
data = pd.concat([data, city_df], axis=1)
data.drop('city', axis=1, inplace=True)

# Eliminamos la columna 'week_start_date' por ser de tipo fecha (adáptalo según tus necesidades)
data.drop('week_start_date', axis=1, inplace=True)

# Dividimos los datos en conjuntos de entrenamiento y prueba
X = data.drop('total_cases', axis=1)
y = data['total_cases']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Escalamos las características para el SVR
scaler_X = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)

scaler_y = StandardScaler()
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1)).ravel()

# %%
X.isna().sum()
# Out:
# year                                     0
# weekofyear                               0
# ndvi_ne                                  0
# ndvi_nw                                  0
# ndvi_se                                  0
# ndvi_sw                                  0
# precipitation_amt_mm                     0
# reanalysis_air_temp_k                    0
# reanalysis_avg_temp_k                    0
# reanalysis_dew_point_temp_k              0
# reanalysis_max_air_temp_k                0
# reanalysis_min_air_temp_k                0
# reanalysis_precip_amt_kg_per_m2          0
# reanalysis_relative_humidity_percent     0
# reanalysis_sat_precip_amt_mm             0
# reanalysis_specific_humidity_g_per_kg    0
# reanalysis_tdtr_k                        0
# station_avg_temp_c                       0
# station_diur_temp_rng_c                  0
# station_max_temp_c                       0
# station_min_temp_c                       0
# station_precip_mm                        0
# city_iq                                  0
# city_sj                                  0
# dtype: int64

# %%
# 2. Construcción del Modelo:

model_svr = SVR(C=1.0, epsilon=0.1, kernel='rbf') #kernel='poly', degree=3
model_svr.fit(X_train_scaled, y_train_scaled)

y_pred_scaled = model_svr.predict(X_test_scaled)
#
y_pred_scaled = y_pred_scaled.reshape(-1, 1)
#
y_pred = scaler_y.inverse_transform(y_pred_scaled)

# %%
# 3. Evaluación del Modelo:

# Error Absoluto medio:
mae = mean_absolute_error(y_test, y_pred)
print(f"Error Absoluto Medio: {mae}\n")

mse = mean_squared_error(y_test, y_pred)
print(f"Error cuadrático medio: {mse}\n")

#Coeficiente de determinacion:
r2 = r2_score(y_test,  y_pred)
print(f"Coeficiente de Determinación R^2: {r2}")
# Out:
# Error Absoluto Medio: 17.517037829628734
#
# Error cuadrático medio: 2051.4094539128473
#
# Coeficiente de Determinación R^2: 0.16800905994193915

# %%
# Valores reales vs predicciones:
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label="Valores Reales", color="blue")
plt.plot(y_pred, label="Predicciones", color="red", linestyle="--")
plt.legend()
plt.title("Valores Reales vs Predicciones")
plt.show()

# %% [markdown]
# ### ver de AJUSTAR HIPERPARAMETROS de AMBOS MODELOS y PROBAR lo DADO en las ultimas CLASES.... 27/10/23

# %% [markdown]
# en el archivo "DESAFIO_FeaturesSelection_CACERES_v241023" realice ajustes y pruebas de hipérametros para el modelo SVR
# * El mejor kernel es: poly con un R2 de: -0.05163664202881457
# * El mejor grado para el kernel polinómico es: 3 con un MSE de: 3375.880647626891

# %% [markdown]
# ## CROSS-VALIDATION SVR

# %%
# from sklearn.svm import SVR
# from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# Instancia del modelo con escalado
svr_pipeline = make_pipeline(StandardScaler(), SVR())

# Validación cruzada
svr_scores = cross_val_score(svr_pipeline, X, y, cv=5, scoring='neg_mean_squared_error')

# Convertimos a RMSE
svr_rmse_scores = np.sqrt(-svr_scores)

# Mostramos resultados
print("Puntuaciones para SVR:", svr_rmse_scores)
print("Media:", svr_rmse_scores.mean())
print("Desviación estándar:", svr_rmse_scores.std())
# Out:
# Puntuaciones para SVR: [80.97060424 42.57833379 20.70321029 19.59176035 13.09022044]
# Media: 35.38682582142737
# Desviación estándar: 24.86696568483013

# %% [markdown]
# ## Mostramos los resultados del Cross Validation para los modelos SVR y RandomForestRegressor

# %% [markdown]
# # RFR
# * Puntuaciones para RandomForestRegressor: [77.13803397 41.08119662 30.50099024 22.95638555 13.12343365]
# * Media: 36.96000800398701
# * Desviación estándar: 22.078317849820266

# %% [markdown]
# # SVR
# * Puntuaciones para SVR: [80.97060424 42.57833379 20.70321029 19.59176035 13.09022044]
# * Media: 35.38682582142737
# * Desviación estándar: 24.86696568483013

# %% [markdown]
# ### Graficamos los resultados del Cross Validation para los modelos

# %%
def plot_scores(scores, label):
    plt.bar(range(len(scores)), scores, alpha=0.7, label=label, color=np.random.rand(3,))
    plt.hlines(np.mean(scores), xmin=0, xmax=len(scores)-1, colors='r', linestyles='dashed', label=f'Media {label}')
    plt.hlines(np.mean(scores) + np.std(scores), xmin=0, xmax=len(scores)-1, colors='b', linestyles='dotted', label=f'Stdev superior {label}')
    plt.hlines(np.mean(scores) - np.std(scores), xmin=0, xmax=len(scores)-1, colors='b', linestyles='dotted', label=f'Stdev inferior {label}')

# Dibuja los resultados de RandomForestRegressor
plot_scores(forest_rmse_scores, "RandomForest")

# Dibuja los resultados de SVR
plot_scores(svr_rmse_scores, "SVR")

# Configuraciones adicionales para el gráfico
plt.title("Puntuaciones de RMSE en la Validación Cruzada")
plt.xlabel("Número de Iteración (Fold)")
plt.ylabel("ERROR CUADRÁTICO MEDIO - RMSE")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# * El gráfico de barras muestra las puntuaciones de RMSE para cada modelo en cada fold. Las líneas discontinuas representan la media de las puntuaciones, y las líneas punteadas representan una desviación estándar por encima y por debajo de la media.

# %% [markdown]
# # Ensamblado para el SVR

# %% [markdown]
# * El Bagging consiste en entrenar múltiples modelos en diferentes subconjuntos de datos y luego combinar sus predicciones. Podemos usar BaggingRegressor de sklearn.ensemble para aplicar bagging al SVR.

# %%
from sklearn.ensemble import BaggingRegressor
#from sklearn.svm import SVR

# Crear un modelo base SVR
svr = SVR(kernel='linear', C=1)

# Aplicar Bagging al SVR
bagging_svr = BaggingRegressor(estimator=svr, n_estimators=10, random_state=42)
bagging_svr.fit(X_train, y_train)

# Predecir y evaluar el modelo
y_pred = bagging_svr.predict(X_test)

# %%
# Evaluando el modelo con bagging
# Crear un modelo Bagging con SVR como base
bagging_svr = BaggingRegressor(estimator=SVR(kernel='linear', C=1), n_estimators=10, random_state=42)

# Calcular las puntuaciones de validación cruzada
scores = cross_val_score(bagging_svr, X, y, cv=5, scoring='r2')  # Aquí estamos usando R^2 como métrica, pero puedes cambiarlo

# Mostrar las puntuaciones
print("Puntuaciones R^2 para cada fold:", scores)
print("Media de puntuaciones R^2:", scores.mean())
print("Desviación estándar de puntuaciones R^2:", scores.std())
# Out:
# Puntuaciones R^2 para cada fold: [-0.13366135 -0.0132823   0.09309974 -0.05550956 -0.65891577]
# Media de puntuaciones R^2: -0.15365385020810074
# Desviación estándar de puntuaciones R^2: 0.26302589866994186

# %%
# Valores reales vs predicciones:
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label="Valores Reales", color="blue")
plt.plot(y_pred, label="Predicciones", color="red", linestyle="--")
plt.legend()
plt.title("Valores Reales vs Predicciones")
plt.show()

# %% [markdown]
# * El Boosting, especialmente AdaBoost, ajusta modelos secuenciales donde cada modelo intenta corregir los errores del modelo anterior. Podemos usar AdaBoostRegressor de sklearn.ensemble para aplicar boosting al SVR.

# %%
from sklearn.ensemble import AdaBoostRegressor

# Crear un modelo base SVR
svr = SVR(kernel='linear', C=1)

# Aplicar AdaBoost al SVR
boosting_svr = AdaBoostRegressor(estimator=svr, n_estimators=50, random_state=42)
boosting_svr.fit(X_train, y_train)

# Predecir y evaluar el modelo
y_pred = boosting_svr.predict(X_test)

# %%
# Evaluando el modelo con boosting
# Crear un modelo AdaBoost con SVR como base
boosting_svr = AdaBoostRegressor(estimator=SVR(kernel='linear', C=1), n_estimators=50, random_state=42)

# Calcular las puntuaciones de validación cruzada
scores = cross_val_score(boosting_svr, X, y, cv=5, scoring='r2')  # Aquí estamos usando R^2 como métrica, pero puedes cambiarlo

# Mostrar las puntuaciones
print("Puntuaciones R^2 para cada fold:", scores)
print("Media de puntuaciones R^2:", scores.mean())
print("Desviación estándar de puntuaciones R^2:", scores.std())
# Out:
# Puntuaciones R^2 para cada fold: [-0.04753156  0.07400561  0.09813853 -0.37600578 -1.94089828]
# Media de puntuaciones R^2: -0.4384582968225749
# Desviación estándar de puntuaciones R^2: 0.7700136792689677

# %%
# Valores reales vs predicciones:
plt.figure(figsize=(10, 6))
plt.plot(y_test.values, label="Valores Reales", color="blue")
plt.plot(y_pred, label="Predicciones", color="red", linestyle="--")
plt.legend()
plt.title("Valores Reales vs Predicciones")
plt.show()

# %% [markdown]
# Es importante señalar que el Boosting generalmente se aplica a modelos que pueden manejar ponderaciones en sus datos de entrenamiento, como los árboles de decisión. El uso de AdaBoost con SVR no es común y podría no ser tan eficiente como con otros modelos.
